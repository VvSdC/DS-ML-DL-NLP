# %% [markdown]
# ## Logging
#
# Logging is a crucial aspect of any application, providing a way to track events, errors and operational information. Python's inbuilt logging module offers a flexible framework for emitting log messages from python programs.

# %% [markdown]
# ### Usage of different log levels
#
# - Debug: Detailed information, typically of interest only when diagnosing problems.
# - Info: Confirmation that things are working as expected
# - Warning: An indication to something unexpected happen or indicative of some problem in the near future. The software is still working as expected.
# - Error: Due to a more serious problem, the software has not been able to perform some function.
# - Critical: A very serious error, indicating that the program itself may be unable to continue running.

# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    force=True  
)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# 2026-02-28 11:19:57,276 - DEBUG - This is a debug message
# 2026-02-28 11:19:57,277 - INFO - This is an info message
# 2026-02-28 11:19:57,278 - WARNING - This is a warning message
# 2026-02-28 11:19:57,279 - ERROR - This is an error message
# 2026-02-28 11:19:57,280 - CRITICAL - This is a critical message

# %% [markdown]
# #### Configuring logging

# %%
logging.basicConfig(
    filename='test_logs.log',
    filemode='w',
    level= logging.DEBUG,
    format= '%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%d-%m-%Y %H:%M:%S',
    force=True
)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

# %% [markdown]
# ### Logging with multiple loggers

# %%
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARN)

logging.basicConfig(
    level= logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%d-%m-%Y %H:%M:%S',
    force=True  
)

# %%
logger1.debug("This is a debug message from logger1")
logger2.warning("This is a warning message from logger2")
# Out:
# 28-02-2026 11:19:57-module1-DEBUG-This is a debug message from logger1
# 28-02-2026 11:19:57-module2-WARNING-This is a warning message from logger2
